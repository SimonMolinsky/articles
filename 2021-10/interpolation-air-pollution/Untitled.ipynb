# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from pyproj import CRS

from pyinterpolate.semivariance import calculate_semivariance
from pyinterpolate.semivariance import TheoreticalSemivariogram
from pyinterpolate.kriging import Krige

# %% [markdown]
# # Read Point Measurements and Canvas

# %%
readings = pd.read_csv('pm25_year_2021_daily.csv', index_col='name')
canvas = gpd.read_file('hexgrid.shp')
canvas['points'] = canvas.centroid

# %%
readings.head()
# Out:
#                              01.01.2021  02.01.2021  03.01.2021  04.01.2021  \
# name
# Legnica - Polarna                  42.8        55.2        41.9        43.6
# Osieczów                           32.7        27.7        28.4        26.3
# Wałbrzych - Wysockiego             23.6        54.3        66.3        64.5
# Wrocław - Na Grobli                28.9        48.1        54.0        57.6
# Zgorzelec - Bohaterów Getta        34.6        35.9        38.2        34.7
#
#                              05.01.2021  06.01.2021  07.01.2021  08.01.2021  \
# name
# Legnica - Polarna                  17.2        14.5        13.0        22.3
# Osieczów                           11.7         4.8         8.7        13.9
# Wałbrzych - Wysockiego             11.1        18.4        18.3        17.6
# Wrocław - Na Grobli                18.9        21.8        17.4        20.9
# Zgorzelec - Bohaterów Getta        17.5        11.1        15.5        21.8
#
#                              09.01.2021  10.01.2021  ...  24.05.2021  \
# name                                                 ...
# Legnica - Polarna                  19.5        19.6  ...         6.8
# Osieczów                            9.8        12.8  ...         7.0
# Wałbrzych - Wysockiego             23.1        27.4  ...         9.0
# Wrocław - Na Grobli                17.8        17.1  ...         6.9
# Zgorzelec - Bohaterów Getta        15.4        18.4  ...        10.6
#
#                              25.05.2021  26.05.2021  27.05.2021  28.05.2021  \
# name
# Legnica - Polarna                   5.4         6.1         5.4         5.3
# Osieczów                            5.8         4.8         4.6         5.7
# Wałbrzych - Wysockiego              5.9         6.2         7.3         5.2
# Wrocław - Na Grobli                 5.5         3.9         4.9         5.4
# Zgorzelec - Bohaterów Getta        15.4         9.2         8.5        11.1
#
#                              29.05.2021  30.05.2021  31.05.2021             x  \
# name
# Legnica - Polarna                   4.6         4.5         3.9  4.752551e+06
# Osieczów                            4.3         5.6         5.3  4.699284e+06
# Wałbrzych - Wysockiego              4.9         4.6         4.8  4.762693e+06
# Wrocław - Na Grobli                 3.5         3.1         2.6  4.814559e+06
# Zgorzelec - Bohaterów Getta         5.7         8.7         5.6  4.671112e+06
#
#                                         y
# name
# Legnica - Polarna            3.140166e+06
# Osieczów                     3.148150e+06
# Wałbrzych - Wysockiego       3.091949e+06
# Wrocław - Na Grobli          3.134107e+06
# Zgorzelec - Bohaterów Getta  3.127473e+06
#
# [5 rows x 153 columns]

# %%
canvas.head()
# Out:
#        id                                           geometry  \
# 0  1265.0  POLYGON ((5262483.451 3241159.737, 5262533.545...
# 1  1267.0  POLYGON ((5266784.217 3208609.593, 5278331.223...
# 2  1266.0  MULTIPOLYGON (((5267077.091 3228607.316, 52670...
# 3  1269.0  POLYGON ((5266784.217 3168609.593, 5278331.223...
# 4  1268.0  POLYGON ((5266784.217 3188609.593, 5278331.223...
#
#                             points
# 0  POINT (5264567.424 3235499.996)
# 1  POINT (5272557.720 3198609.593)
# 2  POINT (5268791.749 3214872.652)
# 3  POINT (5272557.720 3158609.593)
# 4  POINT (5272557.720 3178609.593)

# %%
# Take one reading and x, y columns

# %%
df = readings[['01.01.2021', 'x', 'y']]
df.columns = ['pm2.5', 'x', 'y']

# %%
df.head()
# Out:
#                              pm2.5             x             y
# name
# Legnica - Polarna             42.8  4.752551e+06  3.140166e+06
# Osieczów                      32.7  4.699284e+06  3.148150e+06
# Wałbrzych - Wysockiego        23.6  4.762693e+06  3.091949e+06
# Wrocław - Na Grobli           28.9  4.814559e+06  3.134107e+06
# Zgorzelec - Bohaterów Getta   34.6  4.671112e+06  3.127473e+06

# %% [markdown]
# # Transform `DataFrame` into `GeoDataFrame`

# %%
DATA_CRS = CRS.from_epsg('2180')

# %%
df['geometry'] = gpd.points_from_xy(df['x'], df['y'])
# Out:
# /Users/szymonmolinski/miniconda3/envs/pyintpk/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs=DATA_CRS)

# %%
# Remove NaNs

gdf = gdf.dropna()

# %%
base = canvas.plot(color='white', edgecolor='black', alpha=0.1, figsize=(12, 12))
gdf.plot(ax=base, column='pm2.5', legend=True, vmin=0, vmax=50, cmap='RdYlGn_r')
base.set_title('2021-01-01 Daily PM 2.5 concentrations in Poland');

# %% [markdown]
# # Build Variogram Model

# %%
km_c = 10**3
STEP_SIZE = km_c * 40
MAX_RANGE = km_c * 400
NEIGHBOURS = 8
NUMBER_OF_RANGES = 16

# %%
arr = gdf[['x', 'y', 'pm2.5']].values

semivar = calculate_semivariance(arr,
                                 step_size=STEP_SIZE,
                                 max_range=MAX_RANGE)

# %%
ts = TheoreticalSemivariogram(points_array=arr, empirical_semivariance=semivar, verbose=True)
ts.find_optimal_model()
ts.show_semivariogram()
# Out:
# Model: spherical, error value: 14.7656606198378
# Model: exponential, error value: 14.503144188276451
# Model: linear, error value: 15.795574110078812
# Chosen model: exponential, with value: 14.503144188276451.

# %% [markdown]
# # Interpolate Missing Values with Kriging

# %%
pk = Krige(ts, arr)

# %%
def get_prediction(upts, mdl, nn=8):
    pt = [upts.x, upts.y]
    predicted = mdl.ordinary_kriging(pt, nn)
    return pd.Series([upts, predicted[0], predicted[1]])

# Predict
    
predicted = canvas['points'].apply(get_prediction, mdl=pk)
predicted.columns = ['coordinates', 'yhat', 'error']
    
# Merge with canvas
    
cdf = canvas.join(predicted)
cdf = cdf[['geometry', 'yhat', 'error']]

# %%
base = canvas.plot(color='white', edgecolor='black', alpha=0.1, figsize=(12, 12))
cdf.plot(ax=base, column='yhat', legend=True, vmin=0, vmax=50, cmap='RdYlGn_r')
base.set_title('Interpolated 2021-01-01 Daily PM 2.5 concentrations in Poland');

# %% [markdown]
# ---
